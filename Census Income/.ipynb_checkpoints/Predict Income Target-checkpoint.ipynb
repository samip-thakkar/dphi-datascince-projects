# %% [markdown]
# ### Your task is to build machine learning models to predict the income level (target variable) of the related collaborators in the evaluation set, being 0 a collaborator who has an income less than 50,000 USD annually, and 1 a collaborator who has an income equal to or greater than 50,000 USD annually.

# %%
#Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the data
data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Census_Income/Training_set_census.csv")
data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  \
# 0   23          Private             43               22
# 1   24          Private             34                2
# 2   38          Private             34                2
# 3   33  Not in universe              0                0
# 4   13  Not in universe              0                0
#
#                                 education  wage_per_hour  \
# 0              Some college but no degree              0
# 1              Bachelors degree(BA AB BS)              0
# 2  Masters degree(MA MS MEng MEd MSW MBA)              0
# 3                    High school graduate              0
# 4                                Children              0
#
#   enrolled_in_edu_inst_lastwk                   marital_status  \
# 0       College or university                    Never married
# 1             Not in universe                    Never married
# 2             Not in universe  Married-civilian spouse present
# 3             Not in universe  Married-civilian spouse present
# 4             Not in universe                    Never married
#
#                  major_industry_code           major_occupation_code  ...  \
# 0                          Education  Adm support including clerical  ...
# 1  Finance insurance and real estate  Executive admin and managerial  ...
# 2  Finance insurance and real estate  Executive admin and managerial  ...
# 3        Not in universe or children                 Not in universe  ...
# 4        Not in universe or children                 Not in universe  ...
#
#   country_father country_mother   country_self  \
# 0           Peru           Peru  United-States
# 1  United-States  United-States  United-States
# 2  United-States  United-States  United-States
# 3  United-States  United-States  United-States
# 4  United-States  United-States  United-States
#
#                          citizenship business_or_self_employed  \
# 0  Native- Born in the United States                         0
# 1  Native- Born in the United States                         0
# 2  Native- Born in the United States                         0
# 3  Native- Born in the United States                         0
# 4  Native- Born in the United States                         0
#
#   fill_questionnaire_veteran_admin  veterans_benefits  weeks_worked_in_year  \
# 0                  Not in universe                  2                    30
# 1                  Not in universe                  2                    26
# 2                  Not in universe                  2                    52
# 3                  Not in universe                  2                     0
# 4                  Not in universe                  0                     0
#
#    year income_level
# 0    95            0
# 1    94            0
# 2    94            1
# 3    95            0
# 4    95            0
#
# [5 rows x 41 columns]

# %%
#Get the info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   age                               200000 non-null  int64
#  1   class_of_worker                   200000 non-null  object
#  2   industry_code                     200000 non-null  int64
#  3   occupation_code                   200000 non-null  int64
#  4   education                         200000 non-null  object
#  5   wage_per_hour                     200000 non-null  int64
#  6   enrolled_in_edu_inst_lastwk       200000 non-null  object
#  7   marital_status                    200000 non-null  object
#  8   major_industry_code               200000 non-null  object
#  9   major_occupation_code             200000 non-null  object
#  10  race                              200000 non-null  object
#  11  hispanic_origin                   199408 non-null  object
#  12  sex                               200000 non-null  object
#  13  member_of_labor_union             200000 non-null  object
#  14  reason_for_unemployment           200000 non-null  object
#  15  full_parttime_employment_stat     200000 non-null  object
#  16  capital_gains                     200000 non-null  int64
#  17  capital_losses                    200000 non-null  int64
#  18  dividend_from_Stocks              200000 non-null  int64
#  19  tax_filer_status                  200000 non-null  object
#  20  region_of_previous_residence      200000 non-null  object
#  21  state_of_previous_residence       199523 non-null  object
#  22  d_household_family_stat           200000 non-null  object
#  23  d_household_summary               200000 non-null  object
#  24  migration_msa                     133327 non-null  object
#  25  migration_reg                     133327 non-null  object
#  26  migration_within_reg              133327 non-null  object
#  27  live_1_year_ago                   200000 non-null  object
#  28  migration_sunbelt                 133327 non-null  object
#  29  num_person_Worked_employer        200000 non-null  int64
#  30  family_members_under_18           200000 non-null  object
#  31  country_father                    195478 non-null  object
#  32  country_mother                    195864 non-null  object
#  33  country_self                      197688 non-null  object
#  34  citizenship                       200000 non-null  object
#  35  business_or_self_employed         200000 non-null  int64
#  36  fill_questionnaire_veteran_admin  200000 non-null  object
#  37  veterans_benefits                 200000 non-null  int64
#  38  weeks_worked_in_year              200000 non-null  int64
#  39  year                              200000 non-null  int64
#  40  income_level                      200000 non-null  int64
# dtypes: int64(13), object(28)
# memory usage: 62.6+ MB

# %%
#Check the null entries
data.isna().sum()
# Out:
# age                                     0
# class_of_worker                         0
# industry_code                           0
# occupation_code                         0
# education                               0
# wage_per_hour                           0
# enrolled_in_edu_inst_lastwk             0
# marital_status                          0
# major_industry_code                     0
# major_occupation_code                   0
# race                                    0
# hispanic_origin                       592
# sex                                     0
# member_of_labor_union                   0
# reason_for_unemployment                 0
# full_parttime_employment_stat           0
# capital_gains                           0
# capital_losses                          0
# dividend_from_Stocks                    0
# tax_filer_status                        0
# region_of_previous_residence            0
# state_of_previous_residence           477
# d_household_family_stat                 0
# d_household_summary                     0
# migration_msa                       66673
# migration_reg                       66673
# migration_within_reg                66673
# live_1_year_ago                         0
# migration_sunbelt                   66673
# num_person_Worked_employer              0
# family_members_under_18                 0
# country_father                       4522
# country_mother                       4136
# country_self                         2312
# citizenship                             0
# business_or_self_employed               0
# fill_questionnaire_veteran_admin        0
# veterans_benefits                       0
# weeks_worked_in_year                    0
# year                                    0
# income_level                            0
# dtype: int64

# %%
#Get the numeric and categorical values
num_cols = data.select_dtypes(include=np.number).columns.tolist()
cat_cols = list(set(data.columns) - set(num_cols))
# Out:
# ['live_1_year_ago',
#  'fill_questionnaire_veteran_admin',
#  'state_of_previous_residence',
#  'class_of_worker',
#  'sex',
#  'family_members_under_18',
#  'major_industry_code',
#  'migration_within_reg',
#  'hispanic_origin',
#  'education',
#  'enrolled_in_edu_inst_lastwk',
#  'country_self',
#  'full_parttime_employment_stat',
#  'migration_sunbelt',
#  'race',
#  'major_occupation_code',
#  'country_father',
#  'citizenship',
#  'migration_reg',
#  'marital_status',
#  'country_mother',
#  'region_of_previous_residence',
#  'migration_msa',
#  'd_household_summary',
#  'd_household_family_stat',
#  'member_of_labor_union',
#  'reason_for_unemployment',
#  'tax_filer_status']

# %%
#Divide the data into numeric and categorical
numeric_data = data[num_cols]
categorical_data = data[cat_cols]
categorical_data
# Out:
#                          live_1_year_ago fill_questionnaire_veteran_admin  \
# 0       Not in universe under 1 year old                  Not in universe
# 1                                     No                  Not in universe
# 2                                    Yes                  Not in universe
# 3       Not in universe under 1 year old                  Not in universe
# 4       Not in universe under 1 year old                  Not in universe
# ...                                  ...                              ...
# 199995  Not in universe under 1 year old                  Not in universe
# 199996                               Yes                  Not in universe
# 199997                               Yes                  Not in universe
# 199998  Not in universe under 1 year old                  Not in universe
# 199999  Not in universe under 1 year old                  Not in universe
#
#        state_of_previous_residence   class_of_worker     sex  \
# 0                  Not in universe           Private    Male
# 1                       California           Private    Male
# 2                  Not in universe           Private    Male
# 3                  Not in universe   Not in universe  Female
# 4                  Not in universe   Not in universe    Male
# ...                            ...               ...     ...
# 199995             Not in universe   Not in universe    Male
# 199996             Not in universe           Private    Male
# 199997             Not in universe   Not in universe    Male
# 199998             Not in universe  State government    Male
# 199999             Not in universe   Not in universe    Male
#
#        family_members_under_18                  major_industry_code  \
# 0              Not in universe                            Education
# 1              Not in universe    Finance insurance and real estate
# 2              Not in universe    Finance insurance and real estate
# 3              Not in universe          Not in universe or children
# 4         Both parents present          Not in universe or children
# ...                        ...                                  ...
# 199995    Both parents present          Not in universe or children
# 199996         Not in universe  Personal services except private HH
# 199997         Not in universe          Not in universe or children
# 199998         Not in universe                            Education
# 199999    Both parents present          Not in universe or children
#
#                migration_within_reg   hispanic_origin  \
# 0                               NaN         All other
# 1       Different county same state         All other
# 2                          Nonmover         All other
# 3                               NaN         All other
# 4                               NaN         All other
# ...                             ...               ...
# 199995                          NaN  Mexican-American
# 199996                     Nonmover         All other
# 199997                     Nonmover         All other
# 199998                          NaN         All other
# 199999                          NaN  Mexican-American
#
#                                      education  ...  \
# 0                   Some college but no degree  ...
# 1                   Bachelors degree(BA AB BS)  ...
# 2       Masters degree(MA MS MEng MEd MSW MBA)  ...
# 3                         High school graduate  ...
# 4                                     Children  ...
# ...                                        ...  ...
# 199995                                Children  ...
# 199996     Associates degree-occup /vocational  ...
# 199997                              11th grade  ...
# 199998              Bachelors degree(BA AB BS)  ...
# 199999                                Children  ...
#
#                       migration_reg                   marital_status  \
# 0                               NaN                    Never married
# 1       Different county same state                    Never married
# 2                          Nonmover  Married-civilian spouse present
# 3                               NaN  Married-civilian spouse present
# 4                               NaN                    Never married
# ...                             ...                              ...
# 199995                          NaN                    Never married
# 199996                     Nonmover  Married-civilian spouse present
# 199997                     Nonmover                    Never married
# 199998                          NaN  Married-civilian spouse present
# 199999                          NaN                    Never married
#
#        country_mother region_of_previous_residence migration_msa  \
# 0                Peru              Not in universe           NaN
# 1       United-States                         West    MSA to MSA
# 2       United-States              Not in universe      Nonmover
# 3       United-States              Not in universe           NaN
# 4       United-States              Not in universe           NaN
# ...               ...                          ...           ...
# 199995  United-States              Not in universe           NaN
# 199996  United-States              Not in universe      Nonmover
# 199997  United-States              Not in universe      Nonmover
# 199998  United-States              Not in universe           NaN
# 199999  United-States              Not in universe           NaN
#
#                  d_household_summary                  d_household_family_stat  \
# 0                  Child 18 or older  Child 18+ never marr Not in a subfamily
# 1                        Householder                    Nonfamily householder
# 2                        Householder                              Householder
# 3                  Child 18 or older      Child 18+ ever marr RP of subfamily
# 4       Child under 18 never married    Child <18 never marr not in subfamily
# ...                              ...                                      ...
# 199995  Child under 18 never married    Child <18 never marr not in subfamily
# 199996                   Householder                              Householder
# 199997             Child 18 or older  Child 18+ never marr Not in a subfamily
# 199998                   Householder                              Householder
# 199999  Child under 18 never married    Child <18 never marr not in subfamily
#
#        member_of_labor_union reason_for_unemployment     tax_filer_status
# 0            Not in universe         Not in universe               Single
# 1                         No         Not in universe               Single
# 2            Not in universe         Not in universe  Joint both under 65
# 3            Not in universe         Not in universe  Joint both under 65
# 4            Not in universe         Not in universe             Nonfiler
# ...                      ...                     ...                  ...
# 199995       Not in universe         Not in universe             Nonfiler
# 199996                    No         Not in universe  Joint both under 65
# 199997       Not in universe         Not in universe             Nonfiler
# 199998       Not in universe         Not in universe  Joint both under 65
# 199999       Not in universe         Not in universe             Nonfiler
#
# [200000 rows x 28 columns]

# %% [markdown]
# #### Analysis of numerical data

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   age                         200000 non-null  int64
#  1   industry_code               200000 non-null  int64
#  2   occupation_code             200000 non-null  int64
#  3   wage_per_hour               200000 non-null  int64
#  4   capital_gains               200000 non-null  int64
#  5   capital_losses              200000 non-null  int64
#  6   dividend_from_Stocks        200000 non-null  int64
#  7   num_person_Worked_employer  200000 non-null  int64
#  8   business_or_self_employed   200000 non-null  int64
#  9   veterans_benefits           200000 non-null  int64
#  10  weeks_worked_in_year        200000 non-null  int64
#  11  year                        200000 non-null  int64
#  12  income_level                200000 non-null  int64
# dtypes: int64(13)
# memory usage: 19.8 MB

# %%
numeric_data.nunique(axis = 0)
# Out:
# age                             91
# industry_code                   52
# occupation_code                 47
# wage_per_hour                 1231
# capital_gains                  130
# capital_losses                 113
# dividend_from_Stocks          1497
# num_person_Worked_employer       7
# business_or_self_employed        3
# veterans_benefits                3
# weeks_worked_in_year            53
# year                             2
# income_level                     2
# dtype: int64

# %% [markdown]
# Check the columns with less unique values

# %%
#Get the visualization of correlation matrix
plt.rcParams['figure.figsize'] = 10,10
ax = sns.heatmap(numeric_data.corr(), annot=True)
plt.show()

# %%
#Check the countplot wrt income level
sns.countplot(data['year'], hue=data['income_level'])

# %%
#Check the countplot wrt Veterans benifits
sns.countplot(data['veterans_benefits'], hue=data['income_level'])

# %% [markdown]
# #### Analysis of categorical columns

# %%
categorical_data.head()
# Out:
#                     live_1_year_ago fill_questionnaire_veteran_admin  \
# 0  Not in universe under 1 year old                  Not in universe
# 1                                No                  Not in universe
# 2                               Yes                  Not in universe
# 3  Not in universe under 1 year old                  Not in universe
# 4  Not in universe under 1 year old                  Not in universe
#
#   state_of_previous_residence  class_of_worker     sex  \
# 0             Not in universe          Private    Male
# 1                  California          Private    Male
# 2             Not in universe          Private    Male
# 3             Not in universe  Not in universe  Female
# 4             Not in universe  Not in universe    Male
#
#   family_members_under_18                major_industry_code  \
# 0         Not in universe                          Education
# 1         Not in universe  Finance insurance and real estate
# 2         Not in universe  Finance insurance and real estate
# 3         Not in universe        Not in universe or children
# 4    Both parents present        Not in universe or children
#
#           migration_within_reg hispanic_origin  \
# 0                          NaN       All other
# 1  Different county same state       All other
# 2                     Nonmover       All other
# 3                          NaN       All other
# 4                          NaN       All other
#
#                                 education  ...                migration_reg  \
# 0              Some college but no degree  ...                          NaN
# 1              Bachelors degree(BA AB BS)  ...  Different county same state
# 2  Masters degree(MA MS MEng MEd MSW MBA)  ...                     Nonmover
# 3                    High school graduate  ...                          NaN
# 4                                Children  ...                          NaN
#
#                     marital_status country_mother  \
# 0                    Never married           Peru
# 1                    Never married  United-States
# 2  Married-civilian spouse present  United-States
# 3  Married-civilian spouse present  United-States
# 4                    Never married  United-States
#
#   region_of_previous_residence migration_msa           d_household_summary  \
# 0              Not in universe           NaN             Child 18 or older
# 1                         West    MSA to MSA                   Householder
# 2              Not in universe      Nonmover                   Householder
# 3              Not in universe           NaN             Child 18 or older
# 4              Not in universe           NaN  Child under 18 never married
#
#                    d_household_family_stat member_of_labor_union  \
# 0  Child 18+ never marr Not in a subfamily       Not in universe
# 1                    Nonfamily householder                    No
# 2                              Householder       Not in universe
# 3      Child 18+ ever marr RP of subfamily       Not in universe
# 4    Child <18 never marr not in subfamily       Not in universe
#
#   reason_for_unemployment     tax_filer_status
# 0         Not in universe               Single
# 1         Not in universe               Single
# 2         Not in universe  Joint both under 65
# 3         Not in universe  Joint both under 65
# 4         Not in universe             Nonfiler
#
# [5 rows x 28 columns]

# %%
#Get the unique values count
categorical_data.nunique(axis = 0)
# Out:
# live_1_year_ago                       6
# fill_questionnaire_veteran_admin      6
# state_of_previous_residence         101
# class_of_worker                      18
# sex                                   4
# family_members_under_18              10
# major_industry_code                  48
# migration_within_reg                 19
# hispanic_origin                      19
# education                            34
# enrolled_in_edu_inst_lastwk           6
# country_self                         85
# full_parttime_employment_stat        16
# migration_sunbelt                     7
# race                                 10
# major_occupation_code                30
# country_father                       85
# citizenship                          10
# migration_reg                        17
# marital_status                       14
# country_mother                       85
# region_of_previous_residence         12
# migration_msa                        19
# d_household_summary                  16
# d_household_family_stat              74
# member_of_labor_union                 6
# reason_for_unemployment              12
# tax_filer_status                     12
# dtype: int64
